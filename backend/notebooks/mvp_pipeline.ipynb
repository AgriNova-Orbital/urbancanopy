# %% [markdown]
# # Urban Cooling MVP Pipeline
#
# This notebook demonstrates how the backend logic strings together configuration, source adapters, and city analysis to output priority zones and cooling signatures.

# %%
from pathlib import Path
from urbancanopy.config import load_run_config
from urbancanopy.sources import build_catalog_clients

config_path = Path("../configs/multicity-demo.yml")
cfg = load_run_config(config_path)

clients = build_catalog_clients(cfg.catalogs)
print(f"Focus City: {cfg.focus_city}")
print(f"Catalogs loaded: {list(clients.keys())}")
